# %%
import numpy as np
import pandas as pd
import plotly.offline as pyo
import plotly.graph_objs as go
import plotly.figure_factory as ff # For distplot
from plotly import tools # For heatmap

import dash
import dash_core_components as dcc
import dash_html_components as html

from dash.dependencies import Input, Output, State # For callbacks

import base64 # For encoding images
import json

# %% [markdown]
# Hover Data
# Whenever we hover over a point on the scatter plot it shows the information of that point
# Click Data
# Whenever you click a point then the information of that point is reveaaled
# Select Data
# After selecting the data using lasso or box select, the number of points selected all their information is displayed

# %% [markdown]
# #### Hover Over Data

# %%
app = dash.Dash()

df = pd.read_csv('wheels.csv')

app.layout = html.Div([
    html.Div([
    dcc.Graph(
        id='wheels-plot',
        figure={
            'data': [
                go.Scatter(
                    x = df['color'],
                    y = df['wheels'],
                    dy = 1,
                    mode = 'markers',
                    marker = {
                        'size': 12,
                        'color': 'rgb(51,204,153)',
                        'line': {'width': 2}
                        }
                )
            ],
            'layout': go.Layout(
                title = 'Wheels & Colors Scatterplot',
                xaxis = {'title': 'Color'},
                yaxis = {'title': '# of Wheels','nticks':3},
                hovermode='closest'
            )
        }
    )], style={'width':'30%', 'float':'left'}),

    html.Div([
    html.Pre(id='hover-data', style={'paddingTop':35})
    ], style={'width':'30%'})
])

@app.callback(
    Output('hover-data', 'children'),
    [Input('wheels-plot', 'hoverData')]) 
# Cant change hoverData, it is the info that you get when hover over a point
def callback_image(hoverData):
    return json.dumps(hoverData, indent=2)

if __name__ == '__main__':
    app.run_server()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [16/Sep/2020 00:11:53] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:11:53] "GET /_dash-component-suites/dash_renderer/polyfill@7.v1_4_1m1590427439.8.7.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:11:53] "GET /_dash-component-suites/dash_renderer/prop-types@15.v1_4_1m1590427439.7.2.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:11:53] "GET /_dash-component-suites/dash_renderer/react@16.v1_4_1m1590427439.13.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:11:53] "GET /_dash-component-suites/dash_renderer/react-dom@16.v1_4_1m1590427439.13.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:11:53] "GET /_dash-component-suites/dash_html_components/dash_html_components.v1_0_3m1590427452.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:11:53] "GET /_dash-component-suites/dash_core_components/dash_core_components.v1_10_0m1590427446.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:11:53] "GET /_dash-component-suites/dash_core_components/dash_core_components-shared.v1_10_0m1590427446.js HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:11:53] "GET /_dash-component-suites/dash_renderer/dash_renderer.v1_4_1m1590427439.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:11:54] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:11:54] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:11:54] "GET /_favicon.ico?v=1.12.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:11:54] "GET /_dash-component-suites/dash_core_components/async-graph.v1_10_0m1588696753.js HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:11:54] "GET /_dash-component-suites/dash_core_components/async-plotlyjs.v1_10_0m1588696753.js HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:11:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:11:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:11:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:12:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:12:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:12:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:12:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:12:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:12:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:12:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:12:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:12:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:12:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:12:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:12:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:12:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:12:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:12:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:12:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:12:14] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:12:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:13:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:13:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:13:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:13:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:13:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:13:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:13:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:14:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:14:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:14:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:14:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:14:48] "POST /_dash-update-component HTTP/1.1" 200 -

# %%
app = dash.Dash()

df = pd.read_csv('wheels.csv')

def encode_image(image_file):
    encoded = base64.b64encode(open(image_file, 'rb').read())
    return 'data:image/png;base64,{}'.format(encoded.decode())

app.layout = html.Div([
    html.Div([
    dcc.Graph(
        id='wheels-plot',
        figure={
            'data': [
                go.Scatter(
                    x = df['color'],
                    y = df['wheels'],
                    dy = 1,
                    mode = 'markers',
                    marker = {
                        'size': 12,
                        'color': 'rgb(51,204,153)',
                        'line': {'width': 2}
                        }
                )
            ],
            'layout': go.Layout(
                title = 'Wheels & Colors Scatterplot',
                xaxis = {'title': 'Color'},
                yaxis = {'title': '# of Wheels','nticks':3},
                hovermode='closest'
            )
        }
    )], style={'width':'30%', 'float':'left'}),

    html.Div([
    html.Img(id='hover-image', src='children', height=300)
    ], style={'paddingTop':35})
])

@app.callback(
    Output('hover-image', 'src'), # Instead of overriding the children component which is text , we override the src component
    [Input('wheels-plot', 'hoverData')])
def callback_image(hoverData):
    wheel=hoverData['points'][0]['y']
    color=hoverData['points'][0]['x']
    path = 'Images/'
    return encode_image(path+df[(df['wheels']==wheel) & \
    (df['color']==color)]['image'].values[0])

if __name__ == '__main__':
    app.run_server()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [16/Sep/2020 00:16:10] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:16:10] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:16:10] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:16:10] "GET /children HTTP/1.1" 200 -
# [2020-09-16 00:16:11,590] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 35, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 1032, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 967, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-3-abf86ac38dc0>", line 45, in callback_image
#     wheel=hoverData['points'][0]['y']
# TypeError: 'NoneType' object is not subscriptable
# 127.0.0.1 - - [16/Sep/2020 00:16:11] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [16/Sep/2020 00:16:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:16:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:16:30] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:16:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:16:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:16:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:18:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:18:25] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:18:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:18:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:18:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:18:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:18:30] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:18:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:18:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:18:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:18:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:18:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:18:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:18:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:18:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:18:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:18:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:18:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:18:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:18:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:18:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:18:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:18:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:18:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:18:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:18:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:18:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:18:51] "POST /_dash-update-component HTTP/1.1" 200 -

# %% [markdown]
# #### Click Data

# %%
app = dash.Dash()

df = pd.read_csv('wheels.csv')

def encode_image(image_file):
    encoded = base64.b64encode(open(image_file, 'rb').read())
    return 'data:image/png;base64,{}'.format(encoded.decode())

app.layout = html.Div([
    html.Div([
    dcc.Graph(
        id='wheels-plot',
        figure={
            'data': [
                go.Scatter(
                    x = df['color'],
                    y = df['wheels'],
                    dy = 1,
                    mode = 'markers',
                    marker = {
                        'size': 12,
                        'color': 'rgb(51,204,153)',
                        'line': {'width': 2}
                        }
                )
            ],
            'layout': go.Layout(
                title = 'Wheels & Colors Scatterplot',
                xaxis = {'title': 'Color'},
                yaxis = {'title': '# of Wheels','nticks':3},
                hovermode='closest'
            )
        }
    )], style={'width':'30%', 'float':'left'}),

    html.Div([
    html.Img(id='click-image', src='children', height=300)
    ], style={'paddingTop':35})
])

@app.callback(
    Output('click-image', 'src'),
    [Input('wheels-plot', 'clickData')])
def callback_image(clickData):
    wheel=clickData['points'][0]['y']
    color=clickData['points'][0]['x']
    path = 'Images/'
    return encode_image(path+df[(df['wheels']==wheel) & \
    (df['color']==color)]['image'].values[0])

if __name__ == '__main__':
    app.run_server()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [16/Sep/2020 00:19:12] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:19:12] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:19:12] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:19:12] "GET /children HTTP/1.1" 200 -
# [2020-09-16 00:19:12,789] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 35, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 1032, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 967, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-4-35e7fed662b5>", line 45, in callback_image
#     wheel=clickData['points'][0]['y']
# TypeError: 'NoneType' object is not subscriptable
# 127.0.0.1 - - [16/Sep/2020 00:19:12] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [16/Sep/2020 00:19:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:19:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:19:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:19:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:19:30] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:19:30] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:19:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:19:35] "POST /_dash-update-component HTTP/1.1" 200 -

# %% [markdown]
# #### Select Data

# %%
# Use Lasso Select or Box select
app = dash.Dash()

df = pd.read_csv('wheels.csv')

app.layout = html.Div([
    html.Div([
    dcc.Graph(
        id='wheels-plot',
        figure={
            'data': [
                go.Scatter(
                    x = df['color'],
                    y = df['wheels'],
                    dy = 1,
                    mode = 'markers',
                    marker = {
                        'size': 12,
                        'color': 'rgb(51,204,153)',
                        'line': {'width': 2}
                        }
                )
            ],
            'layout': go.Layout(
                title = 'Wheels & Colors Scatterplot',
                xaxis = {'title': 'Color'},
                yaxis = {'title': '# of Wheels','nticks':3},
                hovermode='closest'
            )
        }
    )], style={'width':'30%', 'display':'inline-block'}),

    html.Div([
    html.Pre(id='selection', style={'paddingTop':25})
    ], style={'width':'30%', 'display':'inline-block', 'verticalAlign':'top'})
])

@app.callback(
    Output('selection', 'children'),
    [Input('wheels-plot', 'selectedData')])
def callback_image(selectedData):
    return json.dumps(selectedData, indent=2)

if __name__ == '__main__':
    app.run_server()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)

# %%
app = dash.Dash()

# create x and y arrays
np.random.seed(10)
x1 = np.linspace(0.1,5,50)
x2 = np.linspace(5.1,10,50)
y = np.random.randint(0,50,50)

# create three "half DataFrames"
df1 = pd.DataFrame({'x': x1, 'y': y})
df2 = pd.DataFrame({'x': x1, 'y': y})
df3 = pd.DataFrame({'x': x2, 'y': y})

# combine them into one DataFrame
df = pd.concat([df1,df2,df3])

app.layout = html.Div([
    html.Div([
    dcc.Graph(
        id='plot',
        figure={
            'data': [
                go.Scatter(
                    x = df['x'],
                    y = df['y'],
                    mode = 'markers'
                )
            ],
            'layout': go.Layout(
                title = 'Random Scatterplot',
                hovermode='closest'
            )
        }
    )], style={'width':'30%', 'display':'inline-block'}),

    html.Div([
    html.Pre(id='density', style={'paddingTop':25})
    ], style={'width':'30%', 'display':'inline-block', 'verticalAlign':'top'})
])

@app.callback(
    Output('density', 'children'),
    [Input('plot', 'selectedData')])
def return_json(selectedData):
    return json.dumps(selectedData, indent=2)

if __name__ == '__main__':
    app.run_server()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [31/May/2020 17:54:43] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2020 17:54:44] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2020 17:54:44] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2020 17:54:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2020 17:55:10] "POST /_dash-update-component HTTP/1.1" 200 -

# %%
app = dash.Dash()

# create x and y arrays
np.random.seed(10)          # for reproducible results
x1 = np.linspace(0.1,5,50)  # left half
x2 = np.linspace(5.1,10,50) # right half
y = np.random.randint(0,50,50) # 50 random points

# create three "half DataFrames"
df1 = pd.DataFrame({'x': x1, 'y': y})
df2 = pd.DataFrame({'x': x1, 'y': y})
df3 = pd.DataFrame({'x': x2, 'y': y})

# combine them into one DataFrame (df1 and df2 points overlap!)
df = pd.concat([df1,df2,df3])

app.layout = html.Div([
    html.Div([
    dcc.Graph(
        id='plot',
        figure={
            'data': [
                go.Scatter(
                    x = df['x'],
                    y = df['y'],
                    mode = 'markers'
                )
            ],
            'layout': go.Layout(
                title = 'Random Scatterplot',
                hovermode='closest'
            )
        }
    )], style={'width':'30%', 'display':'inline-block'}),

    html.Div([
    html.H1(id='density', style={'paddingTop':25})
    ], style={'width':'30%', 'display':'inline-block', 'verticalAlign':'top'})
])

@app.callback(
    Output('density', 'children'),
    [Input('plot', 'selectedData')])
def find_density(selectedData):
    pts = len(selectedData['points'])
    rng_or_lp = list(selectedData.keys())
    rng_or_lp.remove('points')
    max_x = max(selectedData[rng_or_lp[0]]['x'])
    min_x = min(selectedData[rng_or_lp[0]]['x'])
    max_y = max(selectedData[rng_or_lp[0]]['y'])
    min_y = min(selectedData[rng_or_lp[0]]['y'])
    area = (max_x-min_x)*(max_y-min_y)
    d = pts/area
    return 'Density = {:.2f}'.format(d)

if __name__ == '__main__':
    app.run_server()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)

# %% [markdown]
# ### Updating the Graph

# %%
app = dash.Dash()

df = pd.read_csv('mpg.csv')
# Add a random "jitter" to model_year to spread out the plot
df['year'] = np.random.randint(-4,5,len(df))*0.10 + df['model_year']

app.layout = html.Div([
    dcc.Graph(
        id='mpg_scatter',
        figure={
            'data': [go.Scatter(
                x = df['year']+1900,  # our "jittered" data
                y = df['mpg'],
                text = df['name'],
                hoverinfo = 'text',
                mode = 'markers'
            )],
            'layout': go.Layout(
                title = 'mpg.csv dataset',
                xaxis = {'title': 'model year'},
                yaxis = {'title': 'miles per gallon'},
                hovermode='closest'
            )
        }
    )
])

if __name__ == '__main__':
    app.run_server()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [16/Sep/2020 00:22:03] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:03] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:03] "GET /_dash-dependencies HTTP/1.1" 200 -

# %%
app = dash.Dash()

df = pd.read_csv('mpg.csv')

# Add a random "jitter" to model_year to spread out the plot
df['year'] = df['model_year'] + np.random.randint(-4,5,len(df))*0.10

app.layout = html.Div([
    html.Div([   # this Div contains our scatter plot
    dcc.Graph(
        id='mpg_scatter',
        figure={
            'data': [go.Scatter(
                x = df['year']+1900,  # our "jittered" data
                y = df['mpg'],
                text = df['name'],
                hoverinfo = 'text + y + x', # Get the x and y on the hover info as well like this
                mode = 'markers'
            )],
            'layout': go.Layout(
                title = 'mpg.csv dataset',
                xaxis = {'title': 'model year'},
                yaxis = {'title': 'miles per gallon'},
                hovermode='closest'
            )
        }
    )], style={'width':'50%','display':'inline-block'}),
    html.Div([  # this Div contains our output graph
    dcc.Graph(
        id='mpg_line',
        figure={
            'data': [go.Scatter(
                x = [0,1],
                y = [0,1],
                mode = 'lines'
            )],
            'layout': go.Layout(
                title = 'acceleration',
                margin = {'l':0}
            )
        }
    )
    ], style={'width':'20%', 'height':'50%','display':'inline-block'})
])

@app.callback(
    Output('mpg_line', 'figure'),
    [Input('mpg_scatter', 'hoverData')])
def callback_graph(hoverData):
    v_index = hoverData['points'][0]['pointIndex']
    fig = {
        'data': [go.Scatter(
            x = [0,1],
            y = [0,60/df.iloc[v_index]['acceleration']],
            mode='lines',
            line={'width':2*df.iloc[v_index]['cylinders']}
        )],
        'layout': go.Layout(
            title = df.iloc[v_index]['name'],
            xaxis = {'visible':False},
            yaxis = {'visible':False, 'range':[0,60/df['acceleration'].min()]},
            margin = {'l':0},
            height = 300
        )
    }
    return fig

if __name__ == '__main__':
    app.run_server()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [16/Sep/2020 00:22:35] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:35] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:35] "GET /_dash-layout HTTP/1.1" 200 -
# [2020-09-16 00:22:36,449] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 35, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 1032, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 967, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-6-3821aee2ec0d>", line 50, in callback_graph
#     v_index = hoverData['points'][0]['pointIndex']
# TypeError: 'NoneType' object is not subscriptable
# 127.0.0.1 - - [16/Sep/2020 00:22:36] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [16/Sep/2020 00:22:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:55] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:55] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:55] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:55] "GET /_favicon.ico?v=1.12.0 HTTP/1.1" 200 -
# [2020-09-16 00:22:56,221] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 35, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 1032, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 967, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-6-3821aee2ec0d>", line 50, in callback_graph
#     v_index = hoverData['points'][0]['pointIndex']
# TypeError: 'NoneType' object is not subscriptable
# 127.0.0.1 - - [16/Sep/2020 00:22:56] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [16/Sep/2020 00:22:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:22:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:28] "POST /_dash-update-component HTTP/1.1" 200 -

# %%
app = dash.Dash()

df = pd.read_csv('mpg.csv')

# Add a random "jitter" to model_year to spread out the plot
df['year'] = df['model_year'] + np.random.randint(-4,5,len(df))*0.10

app.layout = html.Div([
    html.Div([   # this Div contains our scatter plot
    dcc.Graph(
        id='mpg_scatter',
        figure={
            'data': [go.Scatter(
                x = df['year']+1900,  # our "jittered" data
                y = df['mpg'],
                text = df['name'],
                hoverinfo = 'text',
                mode = 'markers'
            )],
            'layout': go.Layout(
                title = 'mpg.csv dataset',
                xaxis = {'title': 'model year'},
                yaxis = {'title': 'miles per gallon'},
                hovermode='closest'
            )
        }
    )], style={'width':'50%','display':'inline-block'}),
    html.Div([  # this Div contains our output graph and vehicle stats
    dcc.Graph(
        id='mpg_line',
        figure={
            'data': [go.Scatter(
                x = [0,1],
                y = [0,1],
                mode = 'lines'
            )],
            'layout': go.Layout(
                title = 'acceleration',
                margin = {'l':0}
            )
        }
    ),
    dcc.Markdown(
        id='mpg_stats'
    )
    ], style={'width':'20%', 'height':'50%','display':'inline-block'})
])

@app.callback(
    Output('mpg_line', 'figure'),
    [Input('mpg_scatter', 'hoverData')])
def callback_graph(hoverData):
    v_index = hoverData['points'][0]['pointIndex']
    fig = {
        'data': [go.Scatter(
            x = [0,1],
            y = [0,60/df.iloc[v_index]['acceleration']],
            mode='lines',
            line={'width':2*df.iloc[v_index]['cylinders']}
        )],
        'layout': go.Layout(
            title = df.iloc[v_index]['name'],
            xaxis = {'visible':False},
            yaxis = {'visible':False, 'range':[0,60/df['acceleration'].min()]},
            margin = {'l':0},
            height = 300
        )
    }
    return fig

@app.callback(
    Output('mpg_stats', 'children'),
    [Input('mpg_scatter', 'hoverData')])
def callback_stats(hoverData):
    v_index = hoverData['points'][0]['pointIndex']
    stats = """
        {} cylinders
        {}cc displacement
        0 to 60mph in {} seconds
        """.format(df.iloc[v_index]['cylinders'],
            df.iloc[v_index]['displacement'],
            df.iloc[v_index]['acceleration'])
    return stats

if __name__ == '__main__':
    app.run_server()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [16/Sep/2020 00:23:47] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:47] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:47] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:47] "GET /_dash-component-suites/dash_core_components/async-markdown.v1_10_0m1588696753.js HTTP/1.1" 200 -
# [2020-09-16 00:23:48,166] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 35, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 1032, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 967, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-7-4ad9b54a4870>", line 53, in callback_graph
#     v_index = hoverData['points'][0]['pointIndex']
# TypeError: 'NoneType' object is not subscriptable
# 127.0.0.1 - - [16/Sep/2020 00:23:48] "POST /_dash-update-component HTTP/1.1" 500 -
# [2020-09-16 00:23:48,173] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1815, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1718, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 35, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1813, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1799, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 1032, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\dash\dash.py", line 967, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-7-4ad9b54a4870>", line 75, in callback_stats
#     v_index = hoverData['points'][0]['pointIndex']
# TypeError: 'NoneType' object is not subscriptable
# 127.0.0.1 - - [16/Sep/2020 00:23:48] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [16/Sep/2020 00:23:48] "GET /_dash-component-suites/dash_core_components/async-highlight.v1_10_0m1588696753.js HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:23:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:11] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Sep/2020 00:24:16] "POST /_dash-update-component HTTP/1.1" 200 -
